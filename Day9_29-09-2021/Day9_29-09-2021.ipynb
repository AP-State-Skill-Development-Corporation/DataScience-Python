# %% [markdown]
# # Day Objectives:
# ## Pandas Dataframes
# - Creating Dataframe using List, Dict, Numpy, Pandas series
# - Dataframe Indexing
# - Dataframe Merging
# - Dataframe Sorting
# - Dataframe Grouping
# - DataFrame Filtering
# - Dataframe - Applying Statastical & math operations on it
# - Saving

# %% [markdown]
# ### Creating Dataframe using List, Dict, Numpy, Pandas series

# %%
import pandas as pd

# %%
li = [[1,2,3],[4,5,6],[6,7,8]]
df1 = pd.DataFrame(li)
df1
# columns and rows index starts from 0
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  6  7  8

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (3, 3)

# %%
df1.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.columns = ["A","B","C"]
df1
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  6  7  8

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.index = ["x","y",'z']
df1
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  6  7  8

# %%
di = {
    "Name" : ["Supriya", "Thanuja", "Ashok", "Srikanth", "sahithi"],
    "Gender" : ["F", "F", "M", "M", "F"],
    "FFood" : ["Chicken","Potato","South dishes", "laddu", "manchuria"]
}
df2 = pd.DataFrame(di)
df2
# Out:
#        Name Gender         FFood
# 0   Supriya      F       Chicken
# 1   Thanuja      F        Potato
# 2     Ashok      M  South dishes
# 3  Srikanth      M         laddu
# 4   sahithi      F     manchuria

# %%
df2.columns
# Out:
# Index(['Name', 'Gender', 'FFood'], dtype='object')

# %%
df2.index = [1,2,3,4,5]
df2
# Out:
#        Name Gender         FFood
# 1   Supriya      F       Chicken
# 2   Thanuja      F        Potato
# 3     Ashok      M  South dishes
# 4  Srikanth      M         laddu
# 5   sahithi      F     manchuria

# %% [markdown]
# ## DataFrame Indexing

# %%
df2["Name"]
# Out:
# 1     Supriya
# 2     Thanuja
# 3       Ashok
# 4    Srikanth
# 5     sahithi
# Name: Name, dtype: object

# %%
type(df2["Name"])
# Out:
# pandas.core.series.Series

# %%
df2["Gender"]
# Out:
# 1    F
# 2    F
# 3    M
# 4    M
# 5    F
# Name: Gender, dtype: object

# %%
df2[["Name", "FFood"]] # accessing subset
# Out:
#        Name         FFood
# 1   Supriya       Chicken
# 2   Thanuja        Potato
# 3     Ashok  South dishes
# 4  Srikanth         laddu
# 5   sahithi     manchuria

# %%
df2[ :1 ]
# Out:
#       Name Gender    FFood
# 1  Supriya      F  Chicken

# %%
df2[ 3:5 ] # it takes default values starts from 0
# Out:
#        Name Gender      FFood
# 4  Srikanth      M      laddu
# 5   sahithi      F  manchuria

# %%
df2[4:5]["FFood"]
# Out:
# 5    manchuria
# Name: FFood, dtype: object

# %% [markdown]
# #

# %% [markdown]
# ## Loc -  accessing other than integer index values
# ## iloc - Accessing Integer Index

# %%
df2.iloc[2]
# Out:
# Name             Ashok
# Gender               M
# FFood     South dishes
# Name: 3, dtype: object

# %%
df2
# Out:
#        Name Gender         FFood
# 1   Supriya      F       Chicken
# 2   Thanuja      F        Potato
# 3     Ashok      M  South dishes
# 4  Srikanth      M         laddu
# 5   sahithi      F     manchuria

# %%
df2.iloc[4]
# Out:
# Name        sahithi
# Gender            F
# FFood     manchuria
# Name: 5, dtype: object

# %%
df2.loc[4, "FFood"]
# Out:
# 'laddu'

# %%
df2.loc[3, ["Name", "FFood"]]
# Out:
# Name            Ashok
# FFood    South dishes
# Name: 3, dtype: object

# %%
df2.loc[[3,2,4], ["Name", "Gender"]]
# Out:
#        Name Gender
# 3     Ashok      M
# 2   Thanuja      F
# 4  Srikanth      M

# %%
df2
# Out:
#        Name Gender         FFood
# 1   Supriya      F       Chicken
# 2   Thanuja      F        Potato
# 3     Ashok      M  South dishes
# 4  Srikanth      M         laddu
# 5   sahithi      F     manchuria

# %%
# what is the gender of srikanth
df2.loc[4, "Gender"]
# Out:
# 'M'

# %%
df2.FFood
# Out:
# 1         Chicken
# 2          Potato
# 3    South dishes
# 4           laddu
# 5       manchuria
# Name: FFood, dtype: object

# %%
df2.set_index("Name", inplace = True)

# %%
df2
# Out:
#          Gender         FFood
# Name
# Supriya       F       Chicken
# Thanuja       F        Potato
# Ashok         M  South dishes
# Srikanth      M         laddu
# sahithi       F     manchuria

# %%
df2.loc["Thanuja"]
# Out:
# Gender         F
# FFood     Potato
# Name: Thanuja, dtype: object

# %%
df2.loc["Srikanth"]["Gender"]
# Out:
# 'M'

# %%
df2.index
# Out:
# Index(['Supriya', 'Thanuja', 'Ashok', 'Srikanth', 'sahithi'], dtype='object', name='Name')

# %%
df2.reset_index(inplace = True)

# %%
df2
# Out:
#        Name Gender         FFood
# 0   Supriya      F       Chicken
# 1   Thanuja      F        Potato
# 2     Ashok      M  South dishes
# 3  Srikanth      M         laddu
# 4   sahithi      F     manchuria

# %% [markdown]
# ## DataFrame Merging

# %%
d2 = {
    "Name" : ["Supriya", "Thanuja", "Srikanth", "sahithi"],
    "Color": ["White", "Blue", "Pink", "Red"],
    "FFood" : ["Chicken","Potato", "laddu", "manchuria"]
}
df3 = pd.DataFrame(d2)
df3
# Out:
#        Name  Color      FFood
# 0   Supriya  White    Chicken
# 1   Thanuja   Blue     Potato
# 2  Srikanth   Pink      laddu
# 3   sahithi    Red  manchuria

# %%
df2
# Out:
#        Name Gender         FFood
# 0   Supriya      F       Chicken
# 1   Thanuja      F        Potato
# 2     Ashok      M  South dishes
# 3  Srikanth      M         laddu
# 4   sahithi      F     manchuria

# %%
pd.concat([df2,df3], axis = 0)
# Out:
#        Name Gender         FFood  Color
# 0   Supriya      F       Chicken    NaN
# 1   Thanuja      F        Potato    NaN
# 2     Ashok      M  South dishes    NaN
# 3  Srikanth      M         laddu    NaN
# 4   sahithi      F     manchuria    NaN
# 0   Supriya    NaN       Chicken  White
# 1   Thanuja    NaN        Potato   Blue
# 2  Srikanth    NaN         laddu   Pink
# 3   sahithi    NaN     manchuria    Red

# %%
pd.concat([df2,df3], axis = 1)
# Out:
#        Name Gender         FFood      Name  Color      FFood
# 0   Supriya      F       Chicken   Supriya  White    Chicken
# 1   Thanuja      F        Potato   Thanuja   Blue     Potato
# 2     Ashok      M  South dishes  Srikanth   Pink      laddu
# 3  Srikanth      M         laddu   sahithi    Red  manchuria
# 4   sahithi      F     manchuria       NaN    NaN        NaN

# %%
df2.append(df3)
# Out:
#        Name Gender         FFood  Color
# 0   Supriya      F       Chicken    NaN
# 1   Thanuja      F        Potato    NaN
# 2     Ashok      M  South dishes    NaN
# 3  Srikanth      M         laddu    NaN
# 4   sahithi      F     manchuria    NaN
# 0   Supriya    NaN       Chicken  White
# 1   Thanuja    NaN        Potato   Blue
# 2  Srikanth    NaN         laddu   Pink
# 3   sahithi    NaN     manchuria    Red

# %%
df3.append(df2)
# Out:
#        Name  Color         FFood Gender
# 0   Supriya  White       Chicken    NaN
# 1   Thanuja   Blue        Potato    NaN
# 2  Srikanth   Pink         laddu    NaN
# 3   sahithi    Red     manchuria    NaN
# 0   Supriya    NaN       Chicken      F
# 1   Thanuja    NaN        Potato      F
# 2     Ashok    NaN  South dishes      M
# 3  Srikanth    NaN         laddu      M
# 4   sahithi    NaN     manchuria      F

# %%
pd.merge(df2,df3) # it returns common data from both df's
# Out:
#        Name Gender      FFood  Color
# 0   Supriya      F    Chicken  White
# 1   Thanuja      F     Potato   Blue
# 2  Srikanth      M      laddu   Pink
# 3   sahithi      F  manchuria    Red

# %%
df2
# Out:
#        Name Gender         FFood
# 0   Supriya      F       Chicken
# 1   Thanuja      F        Potato
# 2     Ashok      M  South dishes
# 3  Srikanth      M         laddu
# 4   sahithi      F     manchuria

# %%
df3
# Out:
#        Name  Color      FFood
# 0   Supriya  White    Chicken
# 1   Thanuja   Blue     Potato
# 2  Srikanth   Pink      laddu
# 3   sahithi    Red  manchuria

# %%
pd.merge(df2,df3, how = "left")
# Out:
#        Name Gender         FFood  Color
# 0   Supriya      F       Chicken  White
# 1   Thanuja      F        Potato   Blue
# 2     Ashok      M  South dishes    NaN
# 3  Srikanth      M         laddu   Pink
# 4   sahithi      F     manchuria    Red

# %%
pd.merge(df2,df3, how = "right")
# Out:
#        Name Gender      FFood  Color
# 0   Supriya      F    Chicken  White
# 1   Thanuja      F     Potato   Blue
# 2  Srikanth      M      laddu   Pink
# 3   sahithi      F  manchuria    Red

# %%
pd.merge(df2,df3, how = "inner") # common data -  intersection
# Out:
#        Name Gender      FFood  Color
# 0   Supriya      F    Chicken  White
# 1   Thanuja      F     Potato   Blue
# 2  Srikanth      M      laddu   Pink
# 3   sahithi      F  manchuria    Red

# %%
pd.merge(df2,df3, how = "outer")  # all data from both df'd - Union
# Out:
#        Name Gender         FFood  Color
# 0   Supriya      F       Chicken  White
# 1   Thanuja      F        Potato   Blue
# 2     Ashok      M  South dishes    NaN
# 3  Srikanth      M         laddu   Pink
# 4   sahithi      F     manchuria    Red

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %% [markdown]
# * left: use only keys from left frame, similar to a SQL left outer join;
# preserve key order.
# * right: use only keys from right frame, similar to a SQL right outer join;
# preserve key order.
# * outer: use union of keys from both frames, similar to a SQL full outer
# join; sort keys lexicographically.
# * inner: use intersection of keys from both frames, similar to a SQL inner
# join; preserve the order of the left keys.

# %% [markdown]
# ## DataFrame Sorting

# %%
df3
# Out:
#        Name  Color      FFood
# 0   Supriya  White    Chicken
# 1   Thanuja   Blue     Potato
# 2  Srikanth   Pink      laddu
# 3   sahithi    Red  manchuria

# %%
df3.sort_index(axis = 0, ascending=False)
# Out:
#        Name  Color      FFood
# 3   sahithi    Red  manchuria
# 2  Srikanth   Pink      laddu
# 1   Thanuja   Blue     Potato
# 0   Supriya  White    Chicken

# %%
df3.sort_index(axis = 1, ascending=False)
# Out:
#        Name      FFood  Color
# 0   Supriya    Chicken  White
# 1   Thanuja     Potato   Blue
# 2  Srikanth      laddu   Pink
# 3   sahithi  manchuria    Red

# %%
df3.sort_index(axis = 1, ascending=True)
# Out:
#    Color      FFood      Name
# 0  White    Chicken   Supriya
# 1   Blue     Potato   Thanuja
# 2   Pink      laddu  Srikanth
# 3    Red  manchuria   sahithi

# %%
df3.sort_values("Name", ascending=False)
# Out:
#        Name  Color      FFood
# 3   sahithi    Red  manchuria
# 1   Thanuja   Blue     Potato
# 0   Supriya  White    Chicken
# 2  Srikanth   Pink      laddu

# %%
df3
# Out:
#        Name  Color      FFood
# 0   Supriya  White    Chicken
# 1   Thanuja   Blue     Potato
# 2  Srikanth   Pink      laddu
# 3   sahithi    Red  manchuria

# %%
df3.sort_values(["FFood", "Color"], ascending= False)
# Out:
#        Name  Color      FFood
# 3   sahithi    Red  manchuria
# 2  Srikanth   Pink      laddu
# 1   Thanuja   Blue     Potato
# 0   Supriya  White    Chicken

# %% [markdown]
# # File Reading

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/LavanyaPolamarasetty/Datasets/master/Classification/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data = pd.read_csv("diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = pd.read_excel("2020-07-25.xlsx")
df
# Out:
#     Unnamed: 0 Roll Number 2020-07-25
# 0            0  17B81A04H1          P
# 1            1  198A5F0019          P
# 2            2  17KD1A0560          P
# 3            3  17KH1A0455          P
# 4            4  1210316262          P
# 5            5  18P31A0555          P
# 6            6  18B01A0211          P
# 7            7    Y18IT048          P
# 8            8  17B81A05B2          P
# 9            9  169X1A04E0          P
# 10          10  14F41A0447          P
# 11          11  17W51D5505          P
# 12          12  18021D0501          P
# 13          13    Y18CS034          P
# 14          14    Y18IT040          P
# 15          15  154M1A0554          P
# 16          16  19025A0433          P
# 17          17   180030816          P
# 18          18  18A31A1248          P
# 19          19    Y18IT020          P
# 20          20  18AT1A0527          P
# 21          21  18121A02D0          P
# 22          22    Y18IT055          P
# 23          23  17NE1A0578          P
# ...

# %%
df.shape
# Out:
# (57, 3)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Roll Number', '2020-07-25'], dtype='object')

# %%
df.head(3) # accessing top gievn rows, default it takes 5
# Out:
#    Unnamed: 0 Roll Number 2020-07-25
# 0           0  17B81A04H1          P
# 1           1  198A5F0019          P
# 2           2  17KD1A0560          P

# %%
df.tail(4) # accessing last rows
# Out:
#     Unnamed: 0 Roll Number 2020-07-25
# 53          53     R141465          P
# 54          54  17JN1A0495          P
# 55          55   170031480          P
# 56          56  2020239167          P

# %%
df.sample() # random sample
# Out:
#     Unnamed: 0 Roll Number 2020-07-25
# 17          17   180030816          P

# %%
df.describe()
# Out:
#        Unnamed: 0
# count   57.000000
# mean    28.000000
# std     16.598193
# min      0.000000
# 25%     14.000000
# 50%     28.000000
# 75%     42.000000
# max     56.000000

# %%
data.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Grouping

# %%
birds = pd.read_csv("https://raw.githubusercontent.com/LavanyaPolamarasetty/Datasets/master/Classification/bird%20data.csv")
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds["type"].unique()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
birds["type"].value_counts() # 6 different teams
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
birds.shape # IPL file
# Out:
# (420, 12)

# %% [raw]
# SW: Swimming Birds
# W: Wading Birds
# T: Terrestrial Birds
# R: Raptors
# P: Scansorial Birds
# SO: Singing Birds

# %%
g_data = birds.groupby("type")
g_data

# %%
g_data.first()
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77

# %%
g_data.last()
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     253  35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    115  98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     203  39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %%
g_data.get_group("T")
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 181  181   43.97   4.64   51.07   3.80   38.76   3.18   55.67   2.88   30.41
# 182  182   44.58   5.76   52.76   4.84   40.47   3.76   56.42   3.31   31.32
# 183  183   20.25   2.35   25.14   1.76   20.17   1.37   27.67   1.41   15.68
# 184  184   48.70   5.46   57.39   3.73   42.56   3.07   52.42   2.85   27.23
# 185  185   35.74   3.91   39.20   2.93   33.01   2.65   42.80   2.18   24.85
# 186  186   37.69   4.18   43.30   3.38   35.00   2.87   49.15   2.37   26.33
# 187  187   31.26   3.60   35.24   2.91   28.62   2.42   39.04   2.32   21.88
# 188  188   30.97   3.65   36.47   2.96   28.03   2.21   37.41   1.99   21.11
# 189  189   30.31   3.36   34.83   2.49   26.36   2.17   34.16   1.88   18.72
# 190  190   32.02   2.99   27.70   2.38   38.27   2.64   53.33   2.71   31.00
# 191  191   32.34   3.17   29.05   2.36   39.64   2.70   55.36   2.51   37.08
# ...

# %%
len(g_data.get_group("T"))
# Out:
# 23

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
for name,g_info in g_data:
    print("**",name,"**", g_info)
# Out:
# ** P **       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %% [markdown]
# # Statastics

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds.min()
# Out:
# id           0
# huml      9.85
# humw      1.14
# ulnal    14.09
# ulnaw        1
# feml     11.83
# femw      0.93
# tibl       5.5
# tibw      0.87
# tarl      7.77
# tarw      0.66
# type         P
# dtype: object

# %%
birds.max()
# Out:
# id          419
# huml        420
# humw      17.84
# ulnal       422
# ulnaw        12
# feml     117.07
# femw      11.64
# tibl        240
# tibw      11.03
# tarl        175
# tarw      14.09
# type          W
# dtype: object

# %%
birds.mean()
# Out:
# id       209.500000
# huml      64.650501
# humw       4.370573
# ulnal     69.115372
# ulnaw      3.597249
# feml      36.872416
# femw       3.220883
# tibl      64.662823
# tibw       3.182339
# tarl      39.229976
# tarw       2.930024
# dtype: float64

# %%
birds["huml"].min()
# Out:
# 9.85

# %%
birds["huml"].median()
# Out:
# 44.18

# %%
birds.var()
# Out:
# id       14735.000000
# huml      2898.158657
# humw         8.148836
# ulnal     3455.649766
# ulnaw        4.781865
# feml       399.163729
# femw         4.094882
# tibl      1431.725183
# tibw         4.329842
# tarl       537.512389
# tarw         4.777165
# dtype: float64

# %%
birds.std()
# Out:
# id       121.387808
# huml      53.834549
# humw       2.854617
# ulnal     58.784775
# ulnaw      2.186747
# feml      19.979082
# femw       2.023581
# tibl      37.838145
# tibw       2.080827
# tarl      23.184313
# tarw       2.185673
# dtype: float64

# %%
birds.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %%
birds["type"].mode()
# Out:
# 0    SO
# dtype: object

# %% [markdown]
# #

# %% [markdown]
# # Saving

# %%
type(birds.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB
# NoneType

# %%
result = birds.describe()

# %%
result.to_csv( "bird_result.csv")

# %%
result.to_excel("birds_des.xlsx")
