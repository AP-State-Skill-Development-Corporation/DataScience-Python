# %% [markdown]
# ### Supervised Learning
# Regression
# - target has continous values
# Classification
# - target has discrete values

# %% [markdown]
# #### Simple Linear Regression
# - y=mx+c
# - one independant variable and one dependant variable

# %%
#get the data
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/headbrain.csv")

# %%
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
# data exploration
df.isna().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender                 0
# Age Range              0
# Head Size(cm^3)        0
# Brain Weight(grams)    0
# dtype: int64

# %%
x=df["Head Size(cm^3)"].values.reshape(-1,1)
x
# Out:
# array([[4512],
#        [3738],
#        [4261],
#        [3777],
#        [4177],
#        [3585],
#        [3785],
#        [3559],
#        [3613],
#        [3982],
#        [3443],
#        [3993],
#        [3640],
#        [4208],
#        [3832],
#        [3876],
#        [3497],
#        [3466],
#        [3095],
#        [4424],
#        [3878],
#        [4046],
#        [3804],
#        [3710],
#        [4747],
#        [4423],
#        [4036],
#        [4022],
#        [3454],
#        [4175],
#        [3787],
#        [3796],
#        [4103],
#        [4161],
#        [4158],
#        [3814],
#        [3527],
#        [3748],
#        [3334],
#        [3492],
#        [3962],
#        [3505],
#        [4315],
#        [3804],
#        [3863],
#        [4034],
#        [4308],
#        [3165],
#        [3641],
#        [3644],
#        [3891],
#        [3793],
#        [4270],
#        [4063],
#        [4012],
#        [3458],
#        [3890],
#        [4166],
# ...

# %%
y=df["Brain Weight(grams)"]

# %%
# select an algoritm
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
# build the model
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 325.5734210494428

# %%
lr.coef_
# Out:
# array([0.26342934])

# %%
### Evaluating the model
from sklearn.metrics import r2_score,mean_squared_error

# %%
help(r2_score)
# Out:
# Help on function r2_score in module sklearn.metrics._regression:
#
# r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')
#     R^2 (coefficient of determination) regression score function.
#
#     Best possible score is 1.0 and it can be negative (because the
#     model can be arbitrarily worse). A constant model that always
#     predicts the expected value of y, disregarding the input features,
#     would get a R^2 score of 0.0.
#
#     Read more in the :ref:`User Guide <r2_score>`.
#
#     Parameters
#     ----------
#     y_true : array-like of shape (n_samples,) or (n_samples, n_outputs)
#         Ground truth (correct) target values.
#
#     y_pred : array-like of shape (n_samples,) or (n_samples, n_outputs)
#         Estimated target values.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Sample weights.
#
# ...

# %%
lr.predict([[4512]])
# Out:
# array([1514.16660083])

# %%
y_pred=lr.predict(x)
y_pred
# Out:
# array([1514.16660083, 1310.27229206, 1448.04583661, 1320.5460363 ,
#        1425.9177721 , 1269.96760312, 1322.65347102, 1263.11844029,
#        1277.34362462, 1374.5490509 , 1232.56063691, 1377.44677363,
#        1284.45621679, 1434.08408162, 1335.03464997, 1346.62554091,
#        1246.78582124, 1238.61951172, 1140.88722677, 1490.98481895,
#        1347.15239959, 1391.40852862, 1327.65862847, 1302.89627056,
#        1576.07249561, 1490.72138961, 1388.77423523, 1385.08622448,
#        1235.45835965, 1425.39091342, 1323.1803297 , 1325.55119375,
#        1406.42400097, 1421.70290266, 1420.91261465, 1330.29292186,
#        1254.68870143, 1312.90658546, 1203.84683891, 1245.46867455,
#        1369.28046411, 1248.89325596, 1462.27102095, 1327.65862847,
#        1343.2009595 , 1388.24737655, 1460.42701557, 1159.32728053,
#        1284.71964613, 1285.50993415, 1350.576981  , 1324.76090573,
#        1450.41670067, 1395.88682739, 1382.45193108, 1236.512077  ,
# ...

# %%
#r2 range lies b/w 0 and 1
r2_score(y,y_pred)
# Out:
# 0.639311719957

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.scatter(df["Head Size(cm^3)"],df["Brain Weight(grams)"],c="red",label="Actual values")
plt.plot(df["Head Size(cm^3)"],y_pred,c="Blue",label="Regression line")
plt.xlabel("Head size")
plt.ylabel("brain weight")
plt.legend()
plt.show()

# %% [markdown]
# Multiple Linear Regression
# - one dependent and multiple independant variables
# - y=b0+b1x1+b2x2+b3x3+.......
# - price of the house

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Regression/kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#correlation coefficient lies b/w -1 to 1
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
x=df.iloc[:,3:]
x
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
y=df["price"]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x)

# %%
r2_score(y,y_pred)
# Out:
# 0.6997471890109157

# %%
x1=df[["sqft_living","grade","sqft_living15","sqft_above"]]
lr.fit(x1,y)
# Out:
# LinearRegression()

# %%
y_pred1=lr.predict(x1)

# %%
r2_score(y,y_pred1)
# Out:
# 0.5419589651239656
